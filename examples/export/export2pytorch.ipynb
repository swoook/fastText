# %% [markdown]
# # Exporting fastText

# %%
import fasttext
import gensim
from mecab import MeCab
import torch
from torch.nn import Embedding

# %% [markdown]
# ## MeCab

# %%
mecab = MeCab()
document = '우리에게 굵직한 지혜들을 건네는 너무나 멋진 영화'
morphemes = mecab.morphs(document)

# %%
morphemes
# Out:
# ['우리', '에게', '굵직', '한', '지혜', '들', '을', '건네', '는', '너무나', '멋진', '영화']

# %%
' '.join(morphemes)
# Out:
# '우리 에게 굵직 한 지혜 들 을 건네 는 너무나 멋진 영화'

# %% [markdown]
# ## fastText

# %%
model = fasttext.load_model('../baseline/tmp/fasttext.bin')
# Out:
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.

# %%
model.get_sentence_vector(' '.join(morphemes))
# Out:
# array([-0.16013725,  0.09005935,  0.00400428, -0.02762699, -0.11783235,
#         0.07976735, -0.03836356,  0.0338936 ,  0.12256839,  0.04571179,
#         0.0437787 ,  0.00462348,  0.16793722, -0.02188173,  0.05547931,
#         0.06301126, -0.00247431, -0.02743533,  0.0066749 ,  0.00479955,
#        -0.00394412, -0.01312571, -0.01293556,  0.047396  , -0.01472647,
#        -0.05767235,  0.08567697,  0.04963464, -0.02022251, -0.04452684,
#         0.06156359, -0.03003763, -0.108027  , -0.06451722,  0.04826152,
#        -0.00611135, -0.02877227,  0.15473019,  0.01656478,  0.05878403,
#         0.06016641,  0.00974289, -0.00591775,  0.09609663, -0.01499486,
#        -0.08712989,  0.01524194,  0.0886748 , -0.06767763,  0.11617516,
#         0.01487919, -0.02622127, -0.14212397,  0.0141244 , -0.10621323,
#        -0.00182579,  0.03622719, -0.02664652, -0.00377709,  0.01688775,
#        -0.08327223,  0.20424649,  0.03198184,  0.01031437,  0.01716161,
#         0.05074051,  0.09522699,  0.0571514 , -0.09904211, -0.00835343,
#        -0.01200532,  0.04105551,  0.03622741, -0.02977423, -0.02451222,
#         0.1409111 ,  0.01341659, -0.02933594,  0.06204052, -0.01759803,
#         0.05522669,  0.05407077,  0.08537361,  0.04371873, -0.01396976,
#         0.00862959,  0.00226006, -0.00350951,  0.03262985, -0.09934482,
#        -0.13200034, -0.06166136,  0.02625302, -0.01769833, -0.02634944,
#         0.03918435,  0.03435194, -0.11247345,  0.00148539,  0.06503633],
#       dtype=float32)

# %%
embeddings = [model.get_word_vector(morpheme) for _, morpheme in enumerate(morphemes)]
sentence_embedding = sum(embeddings)

# %%
sentence_embedding
# Out:
# array([-5.3881803e+00,  3.3339934e+00, -1.9899374e-01, -1.3103043e+00,
#        -3.9608002e+00,  2.8865838e+00, -1.2759537e+00,  8.7179995e-01,
#         3.7926445e+00,  1.6915550e+00,  9.2647779e-01,  1.7089513e-01,
#         5.7450757e+00, -9.4605929e-01,  1.8335358e+00,  1.7263796e+00,
#         8.6635843e-02, -6.0403693e-01,  3.5892546e-01,  1.9706249e-01,
#        -2.7951634e-01, -5.7524288e-01, -3.7349406e-01,  1.2886776e+00,
#        -5.2843738e-01, -1.6650205e+00,  2.9132798e+00,  1.8467942e+00,
#        -7.1334571e-01, -1.3275107e+00,  2.0068963e+00, -1.0071089e+00,
#        -3.7656507e+00, -2.7547455e+00,  1.5657277e+00, -3.7755519e-03,
#        -1.2180982e+00,  5.3885221e+00,  9.0594316e-01,  1.7410032e+00,
#         2.2105443e+00, -1.5293247e-01, -5.7573795e-01,  3.2544551e+00,
#        -1.6215771e-01, -3.0973606e+00,  2.2906888e-01,  3.1046381e+00,
#        -2.2722075e+00,  3.9370999e+00,  3.6998588e-01, -1.0924687e+00,
#        -4.8797350e+00,  1.3474625e-01, -3.7131810e+00,  5.5600509e-02,
#         1.4173894e+00, -9.6062732e-01, -2.3183893e-01,  2.6175767e-01,
#        -3.3821063e+00,  6.2836967e+00,  1.0647579e+00,  5.0090647e-01,
#         5.4767239e-01,  1.6378717e+00,  2.9533691e+00,  1.5720427e+00,
#        -3.3809133e+00, -5.7196927e-01, -6.3748759e-01,  9.7442299e-01,
#         1.1315812e+00, -8.7472165e-01, -1.0027142e+00,  4.4793611e+00,
#         7.0200688e-01, -9.0903878e-01,  1.8612053e+00, -5.6313729e-01,
#         1.7271974e+00,  1.8389722e+00,  2.9379153e+00,  9.3534994e-01,
#        -1.3098389e-01,  4.2195261e-02, -1.0841608e-01, -4.2778939e-01,
#         1.3022631e+00, -3.6697755e+00, -4.6613040e+00, -2.2839088e+00,
#         9.7922641e-01, -6.2043655e-01, -5.5493176e-01,  1.4617044e+00,
#         1.3830636e+00, -3.6758819e+00,  2.5461391e-01,  2.7658238e+00],
#       dtype=float32)

# %% [markdown]
# ## gensim

# %% [markdown]
# ### Loading fastText with gensim

# %%
model = gensim.models.fasttext.load_facebook_model('../baseline/tmp/fasttext.bin')

# %%
model

# %% [markdown]
# ### vocabulary-index dictionary

# %%
model.wv.key_to_index
# Out:
# {'1': 0,
#  '.': 1,
#  '0': 2,
#  '2': 3,
#  '의': 4,
#  ',': 5,
#  '이': 6,
#  '는': 7,
#  '다': 8,
#  ')': 9,
#  '(': 10,
#  '9': 11,
#  '년': 12,
#  '에': 13,
#  '을': 14,
#  '하': 15,
#  '3': 16,
#  '5': 17,
#  '4': 18,
#  '8': 19,
#  '은': 20,
#  '6': 21,
#  '7': 22,
#  ':': 23,
#  '를': 24,
#  '월': 25,
#  '분류': 26,
#  '일': 27,
#  '고': 28,
#  '-': 29,
#  '가': 30,
#  '있': 31,
#  '에서': 32,
#  '으로': 33,
#  '로': 34,
#  '한': 35,
#  '되': 36,
#  '었': 37,
#  '과': 38,
#  '들': 39,
#  '와': 40,
#  '도': 41,
#  '했': 42,
#  '적': 43,
#  '인': 44,
#  '였': 45,
#  '</s>': 46,
#  '그': 47,
#  '어': 48,
#  '기': 49,
#  '《': 50,
#  '제': 51,
#  '것': 52,
#  '*': 53,
#  '~': 54,
#  '게': 55,
#  '지': 56,
#  '"': 57,
#  '》': 58,
#  '여': 59,
#  '한다': 60,
#  '수': 61,
#  '역': 62,
#  '된': 63,
#  '등': 64,
#  '/': 65,
#  '며': 66,
#  '대': 67,
#  '·': 68,
#  '회': 69,
#  '선수': 70,
#  '영화': 71,
#  '대한민국': 72,
#  '할': 73,
#  '던': 74,
#  '해': 75,
#  '아': 76,
#  '만': 77,
#  '%': 78,
#  '명': 79,
#  '않': 80,
#  '자': 81,
#  '시': 82,
#  '에게': 83,
#  '중': 84,
#  '주': 85,
#  '까지': 86,
#  '미국': 87,
#  '았': 88,
#  '나': 89,
#  '번': 90,
#  '면': 91,
#  '지만': 92,
#  '일본': 93,
#  '없': 94,
#  '사람': 95,
#  '받': 96,
#  '성': 97,
#  '위': 98,
#  '때': 99,
#  '축구': 100,
#  '전': 101,
#  '으며': 102,
#  '#': 103,
#  '된다': 104,
#  '세': 105,
#  '개': 106,
#  '부터': 107,
#  '후': 108,
#  '화': 109,
#  '라고': 110,
#  '사용': 111,
#  '호': 112,
#  '같': 113,
#  '말': 114,
#  '라는': 115,
#  '팀': 116,
#  '학교': 117,
#  '이후': 118,
#  '및': 119,
#  '?': 120,
#  '는데': 121,
#  '두': 122,
#  '면서': 123,
#  '선': 124,
#  '한국': 125,
#  '차': 126,
#  '라': 127,
#  '대학교': 128,
#  '서울': 129,
#  '–': 130,
#  '보': 131,
#  '대한': 132,
#  '권': 133,
#  '상': 134,
#  '경기': 135,
#  '|': 136,
#  '지역': 137,
#  '군': 138,
#  '리그': 139,
#  '다고': 140,
#  '!': 141,
#  '때문': 142,
#  '국가': 143,
#  '이름': 144,
#  '시작': 145,
#  '더': 146,
#  '함께': 147,
#  '세계': 148,
#  '다른': 149,
#  '내': 150,
#  '경우': 151,
#  '현재': 152,
#  '살': 153,
#  '위해': 154,
#  '많': 155,
#  '방송': 156,
#  'KBS': 157,
#  'of': 158,
#  '부': 159,
#  '여자': 160,
#  '자신': 161,
#  '기록': 162,
#  '조선': 163,
#  '또한': 164,
#  '대표': 165,
#  'A': 166,
#  '안': 167,
#  '다음': 168,
#  '째': 169,
#  '대학': 170,
#  '사': 171,
#  '당시': 172,
#  '게임': 173,
#  '분': 174,
#  '형': 175,
#  '오': 176,
#  '하나': 177,
#  '신': 178,
#  '서': 179,
#  '다는': 180,
#  '배우': 181,
#  '이나': 182,
#  '가지': 183,
#  'm': 184,
#  '감독': 185,
#  '고등학교': 186,
#  '출신': 187,
#  '작품': 188,
#  '가장': 189,
#  '씨': 190,
#  '계': 191,
#  '구': 192,
#  '시즌': 193,
#  '드라마': 194,
#  '활동': 195,
#  '남': 196,
#  '당': 197,
#  '그러나': 198,
#  '+': 199,
#  '〈': 200,
#  '또는': 201,
#  '데': 202,
#  '..': 203,
#  '위치': 204,
#  '간': 205,
#  '동': 206,
#  '영국': 207,
#  '점': 208,
#  'MBC': 209,
#  '시간': 210,
#  '따라': 211,
#  '‘': 212,
#  '첫': 213,
#  '원': 214,
#  '태어남': 215,
#  '남자': 216,
#  '그리고': 217,
#  '중국': 218,
#  '대회': 219,
#  '아니': 220,
#  '시대': 221,
#  '만들': 222,
#  '지방': 223,
#  '세기': 224,
#  '다시': 225,
#  '올림픽': 226,
#  '의해': 227,
#  '음': 228,
#  '설립': 229,
#  '도시': 230,
#  '전쟁': 231,
#  '보다': 232,
#  '함': 233,
#  '정부': 234,
#  '프랑스': 235,
#  '뒤': 236,
#  'px': 237,
#  '독일': 238,
#  '조': 239,
#  'TV': 240,
#  '사이': 241,
#  '’': 242,
#  '현': 243,
#  '〉': 244,
#  '길': 245,
#  '포함': 246,
#  '사회': 247,
#  '가능': 248,
#  '통해': 249,
#  '참가': 250,
#  'the': 251,
#  '이상': 252,
#  'The': 253,
#  '음악': 254,
#  '알': 255,
#  '스': 256,
#  '비': 257,
#  '동문': 258,
#  '초등': 259,
#  '교육': 260,
#  '네': 261,
#  '좋': 262,
#  '모든': 263,
#  '는다': 264,
#  '우승': 265,
#  '강': 266,
#  '로서': 267,
#  'km': 268,
#  '연구': 269,
#  '역사': 270,
#  '다가': 271,
#  '장': 272,
#  '모두': 273,
#  '왕': 274,
#  '사건': 275,
#  '정치': 276,
#  '으나': 277,
#  '지정': 278,
#  '집': 279,
#  '일부': 280,
#  '공식': 281,
#  '문화': 282,
#  '&': 283,
#  '위한': 284,
#  '처음': 285,
#  '여러': 286,
#  '문제': 287,
#  '졸업': 288,
#  '큰': 289,
#  '사랑': 290,
#  '초': 291,
#  '국제': 292,
#  'SBS': 293,
#  '개발': 294,
#  '위원회': 295,
#  '지원': 296,
#  '소속': 297,
#  '일반': 298,
#  '대통령': 299,
#  '아들': 300,
#  '기술': 301,
#  '크': 302,
#  '**': 303,
#  '곡': 304,
#  '정보': 305,
#  '산': 306,
#  '정도': 307,
#  '총': 308,
#  '속': 309,
#  '제작': 310,
#  'B': 311,
#  '리': 312,
#  '결과': 313,
#  '동안': 314,
#  '출연': 315,
#  '프로그램': 316,
#  '존재': 317,
#  '될': 318,
#  '이용': 319,
#  '진': 320,
#  '최고': 321,
#  '또': 322,
#  'FC': 323,
#  '설치': 324,
#  '중학교': 325,
#  '관계': 326,
#  '약': 327,
#  '거나': 328,
#  '주장': 329,
#  '트': 330,
#  '드': 331,
#  '삼': 332,
#  '야': 333,
#  '나라': 334,
#  'C': 335,
#  '무': 336,
#  '발표': 337,
#  '》(': 338,
#  '구성': 339,
#  '였으며': 340,
#  '곳': 341,
#  '단': 342,
#  '시리즈': 343,
#  '편': 344,
#  '그룹': 345,
#  '정': 346,
#  '변경': 347,
#  'and': 348,
#  '생각': 349,
#  '높': 350,
#  '이전': 351,
#  '대상': 352,
#  '대해': 353,
#  '경제': 354,
#  '섬': 355,
#  '대전': 356,
#  'K': 357,
#  '“': 358,
#  '우리': 359,
#  '법': 360,
#  '센터': 361,
#  '중앙': 362,
#  '운동': 363,
#  '”': 364,
#  '운영': 365,
#  '최초': 366,
#  '가수': 367,
#  '시키': 368,
#  '로부터': 369,
#  '재': 370,
#  '잘': 371,
#  '날': 372,
#  '교수': 373,
#  '승': 374,
#  '「': 375,
#  '앨범': 376,
#  '」': 377,
#  '타': 378,
#  '노래': 379,
#  '아버지': 380,
#  '각': 381,
#  '철도': 382,
#  '니': 383,
#  '전투': 384,
#  '도록': 385,
#  '용': 386,
#  '러시아': 387,
#  '관련': 388,
#  '반': 389,
#  '행정': 390,
#  '유럽': 391,
#  '죽음': 392,
#  '맡': 393,
#  'jpg': 394,
#  '어서': 395,
#  '이러': 396,
#  '진행': 397,
#  '작': 398,
#  '텔레비전': 399,
#  '제국': 400,
#  '과정': 401,
#  '발견': 402,
#  '공격': 403,
#  '불': 404,
#  '예': 405,
#  '죽': 406,
#  '과학': 407,
#  '미': 408,
#  '진출': 409,
#  '도쿄': 410,
#  '자유': 411,
#  '그녀': 412,
#  '천': 413,
#  '부분': 414,
#  '부산': 415,
#  '발생': 416,
#  '테': 417,
#  '이탈리아': 418,
#  '쓰': 419,
#  '층': 420,
#  '새': 421,
#  '구간': 422,
#  '결정': 423,
#  '여성': 424,
#  '별': 425,
#  '생': 426,
#  '볼': 427,
#  '같이': 428,
#  '데뷔': 429,
#  '얻': 430,
#  '키': 431,
#  '관리': 432,
#  '경기도': 433,
#  '프로': 434,
#  '기준': 435,
#  '상태': 436,
#  '필요': 437,
#  '운행': 438,
#  '로마': 439,
#  '노선': 440,
#  '등장': 441,
#  '했으며': 442,
#  'D': 443,
#  '버스': 444,
#  '선거': 445,
#  '의미': 446,
#  '란': 447,
#  'M': 448,
#  '부문': 449,
#  '대부분': 450,
#  '해서': 451,
#  '내용': 452,
#  '패': 453,
#  '고려': 454,
#  's': 455,
#  '아이': 456,
#  '거리': 457,
#  '하지만': 458,
#  '----': 459,
#  '으로서': 460,
#  '철도역': 461,
#  '참여': 462,
#  '음반': 463,
#  '연기': 464,
#  '수상': 465,
#  '기업': 466,
#  '애니메이션': 467,
#  '사업': 468,
#  '金': 469,
#  '상대': 470,
#  '중심': 471,
#  '구조': 472,
#  '이야기': 473,
#  '뜻': 474,
#  '특별': 475,
#  '끝': 476,
#  '형태': 477,
#  '인해': 478,
#  '사망': 479,
#  '외': 480,
#  '인가': 481,
#  '새로운': 482,
#  '특히': 483,
#  '본': 484,
#  '즉': 485,
#  '발매': 486,
#  '조직': 487,
#  '현대': 488,
#  '이것': 489,
#  '계획': 490,
#  '순위': 491,
#  '의원': 492,
#  '李': 493,
#  '배': 494,
#  '사실': 495,
#  '싱글': 496,
#  '처럼': 497,
#  '계속': 498,
#  '시장': 499,
#  'S': 500,
#  '백': 501,
#  '카': 502,
#  '달': 503,
#  '학급': 504,
#  '성우': 505,
#  'U': 506,
#  '열': 507,
#  '모습': 508,
#  'X': 509,
#  '인간': 510,
#  '해당': 511,
#  '기간': 512,
#  '뿐': 513,
#  '됐': 514,
#  '야구': 515,
#  '영향': 516,
#  '→': 517,
#  '—': 518,
#  '회사': 519,
#  '시스템': 520,
#  'in': 521,
#  '후보': 522,
#  '치': 523,
#  '마지막': 524,
#  '바': 525,
#  '주로': 526,
#  '딸': 527,
#  '↔': 528,
#  '국': 529,
#  '매우': 530,
#  '골': 531,
#  '독립': 532,
#  '기관': 533,
#  '교통': 534,
#  '다양': 535,
#  '방면': 536,
#  '물': 537,
#  '중요': 538,
#  '보이': 539,
#  '지구': 540,
#  '×': 541,
#  '자리': 542,
#  '정책': 543,
#  '이유': 544,
#  '대신': 545,
#  '입': 546,
#  '편성': 547,
#  '영어': 548,
#  '인구': 549,
#  '방법': 550,
#  '양': 551,
#  '공동': 552,
#  '위원': 553,
#  '대구': 554,
#  '많이': 555,
#  '인물': 556,
#  '판': 557,
#  '성공': 558,
#  '생활': 559,
#  '겠': 560,
#  '르': 561,
#  '공화국': 562,
#  '산업': 563,
#  '조사': 564,
#  '국민': 565,
#  '모델': 566,
#  '홈페이지': 567,
#  '역할': 568,
#  '월드컵': 569,
#  '지금': 570,
#  '단체': 571,
#  '관한': 572,
#  '승리': 573,
#  '엔': 574,
#  '마을': 575,
#  '전국': 576,
#  '못하': 577,
#  '억': 578,
#  '제도': 579,
#  'F': 580,
#  '사이트': 581,
#  '선거구': 582,
#  '노': 583,
#  'E': 584,
#  '전체': 585,
#  ';': 586,
#  '급': 587,
#  '방식': 588,
#  '제공': 589,
#  '시기': 590,
#  '책': 591,
#  '평가': 592,
#  '코': 593,
#  '식': 594,
#  '구역': 595,
#  '결국': 596,
#  '존': 597,
#  '컵': 598,
#  '친구': 599,
#  '기타': 600,
#  '종': 601,
#  '루': 602,
#  '민족': 603,
#  '기원전': 604,
#  '앞': 605,
#  '협회': 606,
#  '=': 607,
#  '주요': 608,
#  '예술': 609,
#  '개최': 610,
#  '민주당': 611,
#  '작곡': 612,
#  '갖': 613,
#  '쇼': 614,
#  '였으나': 615,
#  '동시': 616,
#  '따르': 617,
#  '류': 618,
#  '온': 619,
#  '몇': 620,
#  '표현': 621,
#  '기능': 622,
#  '생산': 623,
#  '차지': 624,
#  '군사': 625,
#  '한편': 626,
#  '실': 627,
#  '정당': 628,
#  '추가': 629,
#  '어머니': 630,
#  '해야': 631,
#  '아래': 632,
#  '비고': 633,
#  '발': 634,
#  '공개': 635,
#  '가운데': 636,
#  '인천': 637,
#  '학생': 638,
#  '발전': 639,
#  '스타': 640,
#  '소': 641,
#  '우주': 642,
#  '여기': 643,
#  '건설': 644,
#  '작가': 645,
#  'FIFA': 646,
#  '유지': 647,
#  '이루': 648,
#  '초기': 649,
#  '으로써': 650,
#  '김': 651,
#  'O': 652,
#  '으로부터': 653,
#  '교회': 654,
#  '민주': 655,
#  '라디오': 656,
#  '비디오': 657,
#  '폐지': 658,
#  '연도': 659,
#  'R': 660,
#  '공연': 661,
#  '마': 662,
#  '출전': 663,
#  '공사': 664,
#  '연결': 665,
#  '스페인': 666,
#  '시절': 667,
#  '각각': 668,
#  '목록': 669,
#  '찾': 670,
#  '준': 671,
#  '항공': 672,
#  '・': 673,
#  '소설': 674,
#  '개인': 675,
#  '전기': 676,
#  '유명': 677,
#  '가족': 678,
#  '명칭': 679,
#  '공간': 680,
#  '육군': 681,
#  '피': 682,
#  '도로': 683,
#  '티': 684,
#  '통합': 685,
#  '문': 686,
#  '손': 687,
#  'T': 688,
#  'I': 689,
#  '상황': 690,
#  '밤': 691,
#  '결혼': 692,
#  '스포츠': 693,
#  '언어': 694,
#  '경': 695,
#  '공': 696,
#  '장관': 697,
#  '공항': 698,
#  '임': 699,
#  '인민공화국': 700,
#  '열린': 701,
#  '이론': 702,
#  '거의': 703,
#  '계약': 704,
#  'G': 705,
#  '수록': 706,
#  '연속': 707,
#  '잉글랜드': 708,
#  '잡': 709,
#  '반대': 710,
#  '어떤': 711,
#  '직접': 712,
#  '따라서': 713,
#  '웹': 714,
#  '서비스': 715,
#  '역시': 716,
#  '정의': 717,
#  '선정': 718,
#  '규모': 719,
#  '클럽': 720,
#  '시설': 721,
#  '광주': 722,
#  '배경': 723,
#  '서로': 724,
#  '목적': 725,
#  '경상북도': 726,
#  '임명': 727,
#  '취임': 728,
#  '나오': 729,
#  '연합': 730,
#  'a': 731,
#  '그리스': 732,
#  '이르': 733,
#  '없이': 734,
#  '불리': 735,
#  '종합': 736,
#  '본선': 737,
#  '마음': 738,
#  '먼': 739,
#  '건물': 740,
#  'x': 741,
#  '즈': 742,
#  '소련': 743,
#  '너무': 744,
#  '차량': 745,
#  '환경': 746,
#  '자료': 747,
#  '만든': 748,
#  '했으나': 749,
#  'J': 750,
#  '님': 751,
#  '이런': 752,
#  '황제': 753,
#  '거': 754,
#  '방향': 755,
#  '열차': 756,
#  '회장': 757,
#  '하계': 758,
#  '인도': 759,
#  '기본': 760,
#  '파': 761,
#  '『': 762,
#  '작사': 763,
#  '그것': 764,
#  '의회': 765,
#  '담당': 766,
#  '줄': 767,
#  '글': 768,
#  '됨': 769,
#  '능력': 770,
#  '행위': 771,
#  '건': 772,
#  '난': 773,
#  '경찰': 774,
#  '변화': 775,
#  '사상': 776,
#  '자동차': 777,
#  '론': 778,
#  '제외': 779,
#  '국회의원': 780,
#  '표': 781,
#  '기획': 782,
#  '사고': 783,
#  '동물': 784,
#  '달리': 785,
#  '국제공항': 786,
#  '학년': 787,
#  '실시': 788,
#  '아시아': 789,
#  '국립': 790,
#  '활약': 791,
#  '제목': 792,
#  '맞': 793,
#  '시켰': 794,
#  '도입': 795,
#  'V': 796,
#  '컴퓨터': 797,
#  '개통': 798,
#  '자연': 799,
#  '졌': 800,
#  '눈': 801,
#  '시청': 802,
#  '예선': 803,
#  '뉴욕': 804,
#  '전라남도': 805,
#  '\ufeff': 806,
#  '캐나다': 807,
#  '싶': 808,
#  '소재': 809,
#  '최대': 810,
#  '돈': 811,
#  '원래': 812,
#  '막': 813,
#  '낮': 814,
#  '밴드': 815,
#  '공원': 816,
#  '의한': 817,
#  '쿠': 818,
#  '인정': 819,
#  '최': 820,
#  '먹': 821,
#  '의하': 822,
#  '번호': 823,
#  '기독교': 824,
#  '시민': 825,
#  '대학원': 826,
#  '왔': 827,
#  '섬네일': 828,
#  '외국인': 829,
#  '평균': 830,
#  '전자': 831,
#  '멤버': 832,
#  '밖': 833,
#  '개교': 834,
#  '수도': 835,
#  '아닌': 836,
#  '힘': 837,
#  '칸': 838,
#  '요구': 839,
#  '비롯': 840,
#  '저': 841,
#  '알려져': 842,
#  '승강장': 843,
#  '아시안': 844,
#  '형성': 845,
#  '과거': 846,
#  '보통': 847,
#  '거주': 848,
#  '부대': 849,
#  '》,': 850,
#  '사진': 851,
#  '경상남도': 852,
#  '만화': 853,
#  'mm': 854,
#  '종교': 855,
#  '전문': 856,
#  '나이': 857,
#  '출시': 858,
#  '뮤직': 859,
#  '가진': 860,
#  '버전': 861,
#  '채': 862,
#  '측': 863,
#  '기존': 864,
#  '득점': 865,
#  '대해서': 866,
#  '실패': 867,
#  '레': 868,
#  '팔': 869,
#  '병원': 870,
#  '일원': 871,
#  '으면': 872,
#  '삼성': 873,
#  'FM': 874,
#  '어느': 875,
#  '자기': 876,
#  '차트': 877,
#  '형식': 878,
#  '이적': 879,
#  '교장': 880,
#  '모양': 881,
#  '챔피언': 882,
#  '한다는': 883,
#  '비판': 884,
#  '설명': 885,
#  '투수': 886,
#  '사단': 887,
#  '민주주의': 888,
#  'cm': 889,
#  '월드': 890,
#  '므로': 891,
#  '부르': 892,
#  '세력': 893,
#  '혹은': 894,
#  '촬영': 895,
#  '기반': 896,
#  '터미널': 897,
#  '뉴스': 898,
#  '족': 899,
#  '분야': 900,
#  '바로': 901,
#  '회의': 902,
#  '대하': 903,
#  '비슷': 904,
#  '효과': 905,
#  '속도': 906,
#  '행동': 907,
#  '수행': 908,
#  '마다': 909,
#  '선택': 910,
#  '특수': 911,
#  '보호': 912,
#  '병': 913,
#  '위하': 914,
#  '놓': 915,
#  '캐릭터': 916,
#  '케': 917,
#  '채널': 918,
#  '개시': 919,
#  '라운드': 920,
#  '박물관': 921,
#  '전통': 922,
#  '연방': 923,
#  '남부': 924,
#  '석': 925,
#  '걸': 926,
#  '애': 927,
#  '몸': 928,
#  '왕국': 929,
#  '연대': 930,
#  '초대': 931,
#  '확인': 932,
#  '대로': 933,
#  '작전': 934,
#  '쪽': 935,
#  '관': 936,
#  '넘': 937,
#  '부인': 938,
#  '문학': 939,
#  '습니다': 940,
#  '주연': 941,
#  '최종': 942,
#  '는가': 943,
#  '보여': 944,
#  '디지털': 945,
#  '방영': 946,
#  '거쳐': 947,
#  '대사': 948,
#  '예정': 949,
#  '디자인': 950,
#  'UEFA': 951,
#  '경기장': 952,
#  '박사': 953,
#  'H': 954,
#  '의사': 955,
#  '적용': 956,
#  '기자': 957,
#  '교황': 958,
#  '조약': 959,
#  '해군': 960,
#  '연구소': 961,
#  '일제': 962,
#  '직': 963,
#  '이때': 964,
#  '우수': 965,
#  '차이': 966,
#  '인기': 967,
#  '특징': 968,
#  '카드': 969,
#  'P': 970,
#  '자체': 971,
#  '이미': 972,
#  '못': 973,
#  '서울특별시': 974,
#  '본부': 975,
#  '역임': 976,
#  '주민': 977,
#  '특별시': 978,
#  '氏': 979,
#  '강원도': 980,
#  '종류': 981,
#  '주변': 982,
#  '법원': 983,
#  '에너지': 984,
#  '유일': 985,
#  '아프리카': 986,
#  '작업': 987,
#  '분리': 988,
#  '러': 989,
#  '』': 990,
#  '디': 991,
#  '높이': 992,
#  'W': 993,
#  '못했': 994,
#  '군대': 995,
#  '듯': 996,
#  'L': 997,
#  '비교': 998,
#  '는지': 999,
#  ...}

# %% [markdown]
# ### Pretrained embeddings

# %%
model.wv.vectors
# Out:
# array([[-0.19089553, -0.04864176, -0.12746184, ..., -0.20128623,
#         -0.05452869,  0.21092379],
#        [-0.04622136,  0.09959393,  0.03069987, ..., -0.21032026,
#         -0.0100284 , -0.01041338],
#        [-0.0235911 ,  0.09469731, -0.1185493 , ..., -0.18746178,
#          0.04212563,  0.16035339],
#        ...,
#        [-0.50652236,  0.14685082, -0.24950482, ..., -0.15726815,
#          0.6935291 ,  0.5601857 ],
#        [-0.38853964,  0.02418062,  0.0767933 , ..., -0.3630212 ,
#         -0.27333122,  0.4337093 ],
#        [-0.26303595, -0.38537705, -0.3572211 , ...,  0.04461757,
#          0.09841006, -0.07057536]], dtype=float32)

# %% [markdown]
# ### Is the length of `wv.key_to_index` the same as the length of `wv.vectors`?

# %%
assert len(model.wv.key_to_index) == len(model.wv.vectors)

# %% [markdown]
# ### Sentence embedding
#
# 1. https://github.com/RaRe-Technologies/gensim/issues/3015
# 2. https://github.com/RaRe-Technologies/gensim/pull/3188
# 3. https://stackoverflow.com/questions/65397810/whats-the-equivalent-to-get-sentence-vector-for-gensims-fasttext

# %%
mecab = MeCab()
document = '우리에게 굵직한 지혜들을 건네는 너무나 멋진 영화'

# %%
document in model.wv.key_to_index
# Out:
# False

# %%
morphemes = mecab.morphs(document)
morphemes
# Out:
# ['우리', '에게', '굵직', '한', '지혜', '들', '을', '건네', '는', '너무나', '멋진', '영화']

# %%
embeddings = [model.wv.get_vector(morpheme) for _, morpheme in enumerate(morphemes)]
sentence_embedding = sum(embeddings)
sentence_embedding
# Out:
# array([-5.3881803e+00,  3.3339934e+00, -1.9899373e-01, -1.3103043e+00,
#        -3.9608002e+00,  2.8865838e+00, -1.2759537e+00,  8.7179995e-01,
#         3.7926445e+00,  1.6915551e+00,  9.2647779e-01,  1.7089513e-01,
#         5.7450757e+00, -9.4605929e-01,  1.8335358e+00,  1.7263796e+00,
#         8.6635843e-02, -6.0403693e-01,  3.5892546e-01,  1.9706249e-01,
#        -2.7951634e-01, -5.7524288e-01, -3.7349406e-01,  1.2886776e+00,
#        -5.2843738e-01, -1.6650205e+00,  2.9132798e+00,  1.8467942e+00,
#        -7.1334577e-01, -1.3275107e+00,  2.0068963e+00, -1.0071089e+00,
#        -3.7656507e+00, -2.7547455e+00,  1.5657277e+00, -3.7755519e-03,
#        -1.2180982e+00,  5.3885221e+00,  9.0594304e-01,  1.7410032e+00,
#         2.2105443e+00, -1.5293247e-01, -5.7573795e-01,  3.2544551e+00,
#        -1.6215771e-01, -3.0973606e+00,  2.2906888e-01,  3.1046381e+00,
#        -2.2722075e+00,  3.9370999e+00,  3.6998582e-01, -1.0924687e+00,
#        -4.8797350e+00,  1.3474619e-01, -3.7131810e+00,  5.5600509e-02,
#         1.4173894e+00, -9.6062732e-01, -2.3183893e-01,  2.6175767e-01,
#        -3.3821063e+00,  6.2836967e+00,  1.0647578e+00,  5.0090647e-01,
#         5.4767239e-01,  1.6378717e+00,  2.9533691e+00,  1.5720427e+00,
#        -3.3809133e+00, -5.7196927e-01, -6.3748759e-01,  9.7442299e-01,
#         1.1315812e+00, -8.7472165e-01, -1.0027142e+00,  4.4793611e+00,
#         7.0200688e-01, -9.0903878e-01,  1.8612053e+00, -5.6313729e-01,
#         1.7271973e+00,  1.8389722e+00,  2.9379153e+00,  9.3534982e-01,
#        -1.3098389e-01,  4.2195261e-02, -1.0841608e-01, -4.2778939e-01,
#         1.3022631e+00, -3.6697755e+00, -4.6613040e+00, -2.2839088e+00,
#         9.7922641e-01, -6.2043655e-01, -5.5493176e-01,  1.4617044e+00,
#         1.3830636e+00, -3.6758819e+00,  2.5461391e-01,  2.7658238e+00],
#       dtype=float32)

# %%
sentence_embedding = model.wv.get_sentence_vector(morphemes)

# %%
sentence_embedding
# Out:
# array([-0.16013725,  0.09005935,  0.00400428, -0.02762699, -0.11783233,
#         0.07976735, -0.03836356,  0.0338936 ,  0.12256839,  0.04571179,
#         0.0437787 ,  0.00462348,  0.16793722, -0.02188173,  0.05547931,
#         0.06301126, -0.00247431, -0.02743533,  0.0066749 ,  0.00479955,
#        -0.00394412, -0.01312572, -0.01293556,  0.047396  , -0.01472647,
#        -0.05767235,  0.08567697,  0.04963464, -0.02022251, -0.04452683,
#         0.0615636 , -0.03003763, -0.10802699, -0.06451722,  0.04826152,
#        -0.00611135, -0.02877227,  0.15473019,  0.01656478,  0.05878403,
#         0.06016641,  0.00974289, -0.00591775,  0.09609661, -0.01499486,
#        -0.08712989,  0.01524194,  0.08867479, -0.06767762,  0.11617515,
#         0.01487919, -0.02622127, -0.14212398,  0.0141244 , -0.10621322,
#        -0.00182579,  0.03622719, -0.02664652, -0.00377709,  0.01688775,
#        -0.08327223,  0.20424648,  0.03198184,  0.01031437,  0.01716161,
#         0.05074051,  0.09522698,  0.0571514 , -0.09904211, -0.00835343,
#        -0.01200533,  0.0410555 ,  0.03622741, -0.02977423, -0.02451222,
#         0.14091109,  0.01341659, -0.02933594,  0.06204052, -0.01759803,
#         0.05522668,  0.05407077,  0.08537361,  0.04371873, -0.01396976,
#         0.00862958,  0.00226006, -0.00350951,  0.03262985, -0.09934481,
#        -0.13200034, -0.06166135,  0.02625302, -0.01769832, -0.02634944,
#         0.03918435,  0.03435194, -0.11247345,  0.00148539,  0.06503633],
#       dtype=float32)

# %% [markdown]
# ## PyTorch

# %%
embedding = Embedding.from_pretrained(torch.FloatTensor(model.wv.vectors))

# %%
embedding
# Out:
# Embedding(358043, 100)

# %% [markdown]
# ### Indices of the tokens

# %%
tokens = [model.wv.key_to_index[morpheme] for _, morpheme in enumerate(morphemes)]

# %%
tokens
# Out:
# [359, 83, 61033, 35, 5257, 39, 14, 13637, 7, 6661, 5975, 71]

# %%
embeddings = embedding(torch.LongTensor(tokens))

# %%
embeddings
# Out:
# tensor([[-0.4039,  0.4243, -0.2641,  ..., -0.3232, -0.1522,  0.1071],
#         [-0.3133,  0.2569, -0.2068,  ..., -0.1537,  0.4309,  0.0933],
#         [-0.3159, -0.1389,  0.2980,  ..., -0.6312, -0.3703,  0.5739],
#         ...,
#         [-0.8329,  0.3622, -0.2046,  ..., -0.3303,  0.1547, -0.2323],
#         [-0.9337, -0.0201, -0.1198,  ..., -0.1091,  0.1686,  0.5696],
#         [-0.2876,  0.6111,  0.0328,  ..., -0.5097, -0.0914,  0.4112]])

# %%
embeddings.shape
# Out:
# torch.Size([12, 100])

# %%
embeddings.sum(axis=0)
# Out:
# tensor([-5.3882e+00,  3.3340e+00, -1.9899e-01, -1.3103e+00, -3.9608e+00,
#          2.8866e+00, -1.2760e+00,  8.7180e-01,  3.7926e+00,  1.6916e+00,
#          9.2648e-01,  1.7090e-01,  5.7451e+00, -9.4606e-01,  1.8335e+00,
#          1.7264e+00,  8.6636e-02, -6.0404e-01,  3.5893e-01,  1.9706e-01,
#         -2.7952e-01, -5.7524e-01, -3.7349e-01,  1.2887e+00, -5.2844e-01,
#         -1.6650e+00,  2.9133e+00,  1.8468e+00, -7.1335e-01, -1.3275e+00,
#          2.0069e+00, -1.0071e+00, -3.7657e+00, -2.7547e+00,  1.5657e+00,
#         -3.7756e-03, -1.2181e+00,  5.3885e+00,  9.0594e-01,  1.7410e+00,
#          2.2105e+00, -1.5293e-01, -5.7574e-01,  3.2545e+00, -1.6216e-01,
#         -3.0974e+00,  2.2907e-01,  3.1046e+00, -2.2722e+00,  3.9371e+00,
#          3.6999e-01, -1.0925e+00, -4.8797e+00,  1.3475e-01, -3.7132e+00,
#          5.5601e-02,  1.4174e+00, -9.6063e-01, -2.3184e-01,  2.6176e-01,
#         -3.3821e+00,  6.2837e+00,  1.0648e+00,  5.0091e-01,  5.4767e-01,
#          1.6379e+00,  2.9534e+00,  1.5720e+00, -3.3809e+00, -5.7197e-01,
#         -6.3749e-01,  9.7442e-01,  1.1316e+00, -8.7472e-01, -1.0027e+00,
#          4.4794e+00,  7.0201e-01, -9.0904e-01,  1.8612e+00, -5.6314e-01,
#          1.7272e+00,  1.8390e+00,  2.9379e+00,  9.3535e-01, -1.3098e-01,
#          4.2195e-02, -1.0842e-01, -4.2779e-01,  1.3023e+00, -3.6698e+00,
#         -4.6613e+00, -2.2839e+00,  9.7923e-01, -6.2044e-01, -5.5493e-01,
#          1.4617e+00,  1.3831e+00, -3.6759e+00,  2.5461e-01,  2.7658e+00])
